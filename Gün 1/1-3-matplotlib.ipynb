# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
plt.plot([1,2,3,4,5])
plt.show()

# %%
plt.plot([3,2,2,5,4,1])
plt.ylabel('iterasyon')
plt.xlabel('hata miktarı')
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

z = [1,8,27,32,126]
