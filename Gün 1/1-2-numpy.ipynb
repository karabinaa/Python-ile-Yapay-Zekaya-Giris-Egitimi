# %%
import numpy as np

# %%
#DataTypes & Attributes

# %%
# ndarray
a1 = np.array([1,2,3])
a1

# %%
a2 = np.array([[1,2,3.3],[4,5,6.5]])
a2

# %%
a1.ndim, a2.ndim

# %%
a1.size,a2.size

# %%
# pandas ile birlikte kullanırsak

# %%
import pandas as pd

# %%
df = pd.DataFrame(a2)
df

# %%
# #####

# %%
ones = np.ones(10)
ones

# %%
df = pd.DataFrame(ones)
df

# %%
ones = np.ones((10,5))
ones

# %%
df = pd.DataFrame(ones)
df

# %%
zeros = np.zeros((3,4))
df = pd.DataFrame(zeros)
df

# %%
range_array = np.arange(0,10,2)
df = pd.DataFrame(range_array)
df

# %%
random_array = np.random.randint(1,10, size = (3,5))
df = pd.DataFrame(random_array)
df

# %%
random_array = np.random.random((3,5))
df = pd.DataFrame(random_array)
df

# %%
np.unique([1,1,2,3,2,3])

# %%
random_integers = np.random.randint(1,5, size=(10,10))
random_integers

# %%
np.unique(random_integers)

# %%
random_integers[3]

# %%
random_integers[:,4]

# %%
# arrayleri düzenleme ve karşılaştırma

# %%
a1
# Out:
# array([1, 2, 3])

# %%
ones = np.ones(3)
ones
# Out:
# array([1., 1., 1.])

# %%
a1 + ones
# Out:
# array([2., 3., 4.])

# %%
a1 - ones
# Out:
# array([0., 1., 2.])

# %%
a2
# Out:
# array([[1. , 2. , 3.3],
#        [4. , 5. , 6.5]])

# %%
a1 * a2
# Out:
# array([[ 1. ,  4. ,  9.9],
#        [ 4. , 10. , 19.5]])

# %%
a1
# Out:
# array([1, 2, 3])

# %%
a2 = np.random.randint(1,5, size=(3,3))
a2
# Out:
# array([[4, 2, 1],
#        [1, 4, 4],
#        [1, 2, 1]])

# %%
np.dot(a1,a2)
# Out:
# array([ 9, 16, 12])

# %%
np.dot(a2,a1)
# Out:
# array([11, 21,  8])

# %%
a2 % 2
# Out:
# array([[0, 0, 1],
#        [1, 0, 0],
#        [1, 0, 1]])

# %%
a2 ** 2
# Out:
# array([[16,  4,  1],
#        [ 1, 16, 16],
#        [ 1,  4,  1]])

# %%
np.exp(a2)
# Out:
# array([[54.59815003,  7.3890561 ,  2.71828183],
#        [ 2.71828183, 54.59815003, 54.59815003],
#        [ 2.71828183,  7.3890561 ,  2.71828183]])

# %%
a2.sum()
# Out:
# 20

# %%
#pythonda da sum var

# %%
kocamanBirDizi = np.random.random(100000)

# %%
# %timeit sum(kocamanBirDizi)
# Out:
# 3.41 ms ± 19.4 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit np.sum(kocamanBirDizi)
# Out:
# 13.9 μs ± 227 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# biraz da istatistik

# %%
np.var(a2)
# Out:
# 1.7283950617283952

# %%
np.mean(a2)
# Out:
# 2.2222222222222223

# %%
np.std(a2)
# Out:
# 1.314684396244359

# %%
# transpoze alma ve yeniden boyutlandırma

# %%
a1 = np.random.randint(10, size=(6,3))
a2 = np.random.randint(10, size=(2,3,3))

# %%
a1 * a2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 a1 * a2
#
# ValueError: operands could not be broadcast together with shapes (6,3) (2,3,3)

# %%
a2 = a2.reshape(6,3)
a2
# Out:
# array([[6, 7, 7],
#        [1, 8, 5],
#        [1, 6, 6],
#        [8, 9, 0],
#        [4, 7, 1],
#        [9, 9, 0]])

# %%
a1 * a2
# Out:
# array([[42, 21, 42],
#        [ 3, 72, 30],
#        [ 4,  0,  0],
#        [16, 18,  0],
#        [20, 35,  8],
#        [18, 63,  0]])

# %%
a1 = np.random.randint(3, size= (1,5))
a1Transpoze = a1.transpose()
a1Transpoze
# Out:
# array([[2],
#        [2],
#        [0],
#        [2],
#        [1]])

# %%
np.dot(a1,a1Transpoze)
# Out:
# array([[9]])

# %%
# Görüntüleri numpy dizilerine dönüştürme

# %% [markdown]
# <img src="panda.png"/>

# %%
from matplotlib.image import imread
from matplotlib.pyplot import imshow

img = imread('panda.png')
print(type(img))
img[1000:2000,1000:2000,:]

imshow(a)
# Out:
# <class 'numpy.ndarray'>
